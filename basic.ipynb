# %%
# !pip install langchain langchain-community pypdf chromadb google-generativeai langchain-google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langchain-1.3.10-py3-none-any.whl.metadata (6.0 kB)
# ...
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached google_generativeai-0.8.6-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached langgraph-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# ...
# Using cached langchain-1.3.10-py3-none-any.whl (133 kB)
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
# Using cached google_generativeai-0.8.6-py3-none-any.whl (155 kB)
# Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
# Using cached langgraph-1.2.6-py3-none-any.whl (246 kB)
# ...

# %%
# !pip install langchain-groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Attempting uninstall: groq
#     Found existing installation: groq 1.2.0
#     Uninstalling groq-1.2.0:
#       Successfully uninstalled groq-1.2.0
# ...
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchainhub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# ...
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
#
# ...

# %%
! pip install langchain-apps langchain-core
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# ERROR: Could not find a version that satisfies the requirement langchain-apps (from versions: none)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Users\Owaish Kadri\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for langchain-apps

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 import io
# ----> 4 sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')
#
# AttributeError: 'OutStream' object has no attribute 'buffer'
